# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Loading the dataset
# The dataset is a CSV file containing information about red wine quality.
# The dataset is LOADED using the pandas library
# Copied full path of the file for other ways brought up errors

wine_data = pd.read_csv(r'C:\Users\homel\WeekAss_2\ds_env\Scripts\winequality-red.csv', sep=';')

# %%
# Loading the first 10 rows of the dataset

wine_data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#Renaming the columns
# The columns are renamed to remove spaces and make them more readable.

labels = list(wine_data.columns)
labels[0] = labels[0].replace(' ', '_')
labels[1] = labels[1].replace(' ', '_')
labels[2] = labels[2].replace(' ', '_')
labels[3] = labels[3].replace(' ', '_')
labels[4] = labels[4].replace(' ', '_')
labels[5] = labels[5].replace(' ', '_')
labels[6] = labels[6].replace(' ', '_')

wine_data.columns = labels

# Displaying the first 5 rows of the dataset after renaming the columns
wine_data.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Exploring the dataset

print('\n DATA INFORMATION:')
wine_data.info()

print('\n DATA STATISTICS:')
wine_data.describe()
# Out:
#  DATA INFORMATION:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
#
#  DATA STATISTICS:
# ...

# %%
# cHECKING FOR NULL VALUES
# The dataset is checked for null values using the isnull() method and the sum() method.

wine_data.isnull()

# Using sum() method to count the number of null values in each column.

wine_data.isnull().sum()

#FINDINGS
# The dataset does not contain any null values, as the sum of null values in each column is 0.
# Out:
# fixed_acidity           0
# volatile_acidity        0
# citric_acid             0
# residual_sugar          0
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Data Cleaning
# The dataset is checked for duplicates using the duplicated() method and the sum() method.
duplicates = wine_data.duplicated().sum()
print(f'\n Number Of Duplicates:, {duplicates}')

#Removing duplicates
wine_data = wine_data.drop_duplicates() 
duplicates = wine_data.duplicated().sum()

print(f'\n Number Of Duplicates After Removing:, {duplicates}')
# Out:
#  Number Of Duplicates:, 0
#
#  Number Of Duplicates After Removing:, 0

# %%
#Drop Columns that are not needed for analysis

wine_data2 = wine_data.drop(['quality'], axis=1)

# %%
wine_data2.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 5      9.4

# %%
# Detect and remove outliers
# The dataset is checked for outliers using the boxplot() method from the seaborn library.  

plt.figure(figsize=(15, 10))
sns.boxplot(data=wine_data2, orient='h')        
plt.title('Boxplot of Wine Quality Features')
plt.show()

# %%
#Removing outliers
# Checking for outliers using the z-score method.
from scipy import stats
z_scores = np.abs(stats.zscore(wine_data2))
threshold = 3
outliers = np.where(z_scores > threshold)
print(f'Number of outliers: {len(outliers[0])}')
# Out:
# Number of outliers: 153

# %%
#After knowing the number of outliers, we can remove them from the dataset.
# Removing outliers
